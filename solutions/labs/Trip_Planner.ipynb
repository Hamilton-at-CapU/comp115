# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamilton-at-CapU/comp115/blob/main/solutions/labs/Trip_Planner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab: Trip Planner

# %% [markdown]
# List all the authors of your lab (your group members) and your sources of assistance (for example, Runestone, ChatGPT, etc.)
#
# * Author(s):
#
#
# * Sources of Assistance:

# %% [markdown]
# You want to make an app that helps people plan their trips.  Write a program that asks the user how far they will be travelling (in km) and how fast they will be driving (in km/h), then prints out how long it will take them in hours, minutes, and seconds.
#
# Example:
#
# ```
# How far are you travelling (in km)? 100
# How fast will you be driving (in km/h)? 40
# The trip will take you 2 hours, 30 minutes, and 0 seconds.
# ```

# %%
# write your code here

# %% [markdown]
# ### How to Save and Submit Your Work:
#
# > To save this notebook, you will need to copy it to your own Google Drive.  Find the save option near the top-left of this window.
#
# > To share your notebook with me, you will need to click the 'Share' button near the top-right of this window.  Select 'Anyone with the link', and then change 'Viewer' to 'Commenter' and copy the link.  Paste the link into the eLearn assignment.
#
# > I will be able to access your work from the link you submit and will be able to make comments on your submission.
