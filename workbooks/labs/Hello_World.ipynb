# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamilton-at-CapU/comp115/blob/main/workbooks/labs/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab: Hello World

# %% [markdown]
# List all the authors of your lab (your group members) and your sources of assistance (for example, Andrew Hamilton gave some advice, Think Python used for basic syntax, www.w3schools.com used to explain variables, Genini to help fix a bug)
#
# ### Author(s):
# *
#
# ### Sources of Assistance:
# *

# %% [markdown]
# ## Exercise
#
# Write a program that simply prints `Hello <your name>!`, where `<your name>` is your actual name.
#
# Example output:
#
# ```
# Hello Andrew!
# ```

# %% [markdown]
# ### How to Save and Submit Your Work:
#
# 1. Save the notebook by making a copy of it to your own Google Drive using the `File -> Save a copy in Drive` option at the top-left of this window.  Note that you will not be able to save any edits you make until you have made a copy.
#
# 2. To share your notebook with me, click the `Share` button near the top-right of this window.  Select `Anyone with the link`, and then change `Viewer` to `Commenter` and copy the link provided.
#
# 3. Paste the URL into the eLearn assignment.  Please make the URL a hyperlink using the tools in the box above the submission text box.  The 'link' tool (looks like a chain link) should be available once you highlight the URL.
#
# 4. I will access your work from the link you submit and will make comments on your submission (assuming you allowed `Commenter` privilages).

# %% [markdown]
# ## Bonus Challenge
#
# Write a program that asks you for your name, then tells you `Hello <your name>`.  This lab is not being graded, so I'm not really sure what the bonus is...
